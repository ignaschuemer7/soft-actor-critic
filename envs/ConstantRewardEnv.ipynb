# %% [markdown]
# # **<p style="text-align: center;">Aprendizaje por refuerzo - Ingeniería en Inteligencia Artificial</p>**
# ## **<p style="text-align: center;">Trabajo práctico Final - SAC</p>**
#
# #### <p style="text-align: center;">Pettinari Fausto, Schuemer Ignacio, Torres Santiago </p>
# #### <p style="text-align: center;">Profesores: Claudio Pose, Gabriel Torre, Nicolás Romero, Tomás Chimenti</p>

# %% [markdown]
# # **Constant Reward Enviroment - *Entorno de Prueba***

# %%
import gymnasium as gym
from envs import ConstantRewardEnv

# %%
gym.register(
    id="gymnasium_env/ConstantRewardEnv-v0",
    entry_point=ConstantRewardEnv
)
env = gym.make("gymnasium_env/ConstantRewardEnv-v0")

# %% [markdown]
# #### **Logging & Debugging (Random Agent)**

# %%
from torch.utils.tensorboard import SummaryWriter
import sys
import os
sys.path.append(os.path.join('..'))
from src.random_agent import random_agent_loop
# Out:
# 2025-11-23 11:44:07.736054: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-23 11:44:07.818207: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-23 11:44:10.029306: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
seed = 42
# writer = SummaryWriter(f"../runs/ConstantRewardEnv")
writer = None
num_episodes = 500
random_agent_loop(env, num_episodes, writer, seed)
# Out:
# Episode 0: avg batch reward = 1.000
# Episode 10: avg batch reward = 1.000
# Episode 20: avg batch reward = 1.000
# Episode 30: avg batch reward = 1.000
# Episode 40: avg batch reward = 1.000
# Episode 50: avg batch reward = 1.000
# Episode 60: avg batch reward = 1.000
# Episode 70: avg batch reward = 1.000
# Episode 80: avg batch reward = 1.000
# Episode 90: avg batch reward = 1.000
# Episode 100: avg batch reward = 1.000
# Episode 110: avg batch reward = 1.000
# Episode 120: avg batch reward = 1.000
# Episode 130: avg batch reward = 1.000
# Episode 140: avg batch reward = 1.000
# Episode 150: avg batch reward = 1.000
# Episode 160: avg batch reward = 1.000
# Episode 170: avg batch reward = 1.000
# Episode 180: avg batch reward = 1.000
# Episode 190: avg batch reward = 1.000
# Episode 200: avg batch reward = 1.000
# Episode 210: avg batch reward = 1.000
# Episode 220: avg batch reward = 1.000
# Episode 230: avg batch reward = 1.000
# Episode 240: avg batch reward = 1.000
# Episode 250: avg batch reward = 1.000
# Episode 260: avg batch reward = 1.000
# Episode 270: avg batch reward = 1.000
# Episode 280: avg batch reward = 1.000
# Episode 290: avg batch reward = 1.000
# Episode 300: avg batch reward = 1.000
# Episode 310: avg batch reward = 1.000
# Episode 320: avg batch reward = 1.000
# Episode 330: avg batch reward = 1.000
# Episode 340: avg batch reward = 1.000
# Episode 350: avg batch reward = 1.000
# Episode 360: avg batch reward = 1.000
# Episode 370: avg batch reward = 1.000
# Episode 380: avg batch reward = 1.000
# Episode 390: avg batch reward = 1.000
# Episode 400: avg batch reward = 1.000
# Episode 410: avg batch reward = 1.000
# Episode 420: avg batch reward = 1.000
# Episode 430: avg batch reward = 1.000
# Episode 440: avg batch reward = 1.000
# Episode 450: avg batch reward = 1.000
# Episode 460: avg batch reward = 1.000
# Episode 470: avg batch reward = 1.000
# Episode 480: avg batch reward = 1.000
# Episode 490: avg batch reward = 1.000

# %% [markdown]
# ## **SAC Agent**

# %%
from src.SAC import SAC
from src.hyperparameters import SACConfig

# %%
from dataclasses import replace
from src.alpha_scheduler import FixedAlpha

base = SACConfig()
experiment_cfg = SACConfig(
    sac=replace(base.sac, gamma=0.99, tau=0.01, alpha=FixedAlpha(0.1)),
    q_net=replace(base.q_net, hidden_sizes=[10, 10], hidden_layers_act="relu"),
    policy_net=replace(base.policy_net, log_std_min=-10, log_std_max=1, hidden_sizes=[10, 10], hidden_layers_act="relu"),
    buffer=replace(base.buffer, capacity=1000),
    train=replace(base.train, batch_size=64, device="cuda"),
    logger=replace(base.logger, env_name="ConstantRewardEnv", log_dir="../runs")
)

# %%
SAC_agent = SAC(env=env, config=experiment_cfg)
SAC_agent.run_training_loop(num_episodes=2000, tqdm_disable=False, print_rewards=False)
# Out:
#  48%|████▊     | 955/2000 [00:01<00:01, 566.30it/s]/home/ignacio/Documents/Ignacio UdeSa/4to/2do semestre/RL/TPS/RL-SAC/envs/../src/SAC.py:203: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   state=torch.FloatTensor(batch.state).to(self.device),
# /home/ignacio/Documents/Ignacio UdeSa/4to/2do semestre/RL/TPS/RL-SAC/envs/../src/SAC.py:247: UserWarning: Using a target size (torch.Size([64, 64])) that is different to the input size (torch.Size([64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   q1_loss = torch.nn.functional.mse_loss(current_q1, target_q_values)
# /home/ignacio/Documents/Ignacio UdeSa/4to/2do semestre/RL/TPS/RL-SAC/envs/../src/SAC.py:248: UserWarning: Using a target size (torch.Size([64, 64])) that is different to the input size (torch.Size([64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   q2_loss = torch.nn.functional.mse_loss(current_q2, target_q_values)
# 100%|██████████| 2000/2000 [00:09<00:00, 203.44it/s]
# {'total_episodes': 2000,
#  'best_avg_return': np.float64(1.0),
#  'final_avg_return': np.float64(1.0)}
